# %%
# %matplotlib notebook
import random
from itertools import count
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.pyplot import figure
import time as timer

# %% [markdown]
# # Exporting CSV live generated data and plotting

# %%
plt.style.use('fivethirtyeight')

x_vals = []
y_vals = []

index = count()

def animate(i):
    data = pd.read_csv('data.csv')   ###this data is being generated in another file 
    #you can run that file and then run this file to see the live changes in the graph
    #that way you can link any data from any source and plot it live 
    x = data['x_value']             
    y1 = data['total_1']
    y2 = data['total_2']

    plt.subplot(1, 2, 1)
    plt.cla() #clear axis
    plt.plot(x, y1, label='Channel 1')
    plt.legend(loc='upper left')
    
    plt.subplot(1, 2, 2)
    plt.cla() #clear axis
    plt.plot(x, y2, label='Channel 2')
    plt.legend(loc='upper left')
    plt.tight_layout()

ani = FuncAnimation(figure(figsize=(6,3)), animate, interval=1000)

plt.show()
end = timer.time()
print("Total time consumption {:.2f} seconds".format(end-start))
# Out:
# <img src="data:image/png;base64,..." width="600">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-96d3dfa3d001> in <module>
#      29 plt.show()
#      30 end = timer.time()
# ---> 31 print("Total time consumption {:.2f} seconds".format(end-start))
#
# NameError: name 'start' is not defined

# %% [markdown]
# # Randomly Generated Data

# %%
plt.style.use('fivethirtyeight')
x_vals = []
y_vals = []
y1_vals = []

index = count()     #a variable that stores index values --> x-axis count

def animate(i):
    x_vals.append(next(index))
    y_vals.append(random.randint(-5, 100))   #y-axis ranges
    y1_vals.append(random.randint(-10, 100)) #y-axis ranges 
    #to create to plots together use subplot
    plt.subplot(1, 2, 1)
    plt.cla() #clear axis
    plt.plot(x_vals, y_vals, label='Channel 1')
    plt.legend(loc='upper left')   
    #subplot
    plt.subplot(1, 2, 2)
    plt.cla() #clear axis 
    plt.plot(x_vals, y1_vals, label='Channel 2')
    plt.legend(loc='upper left')
    plt.tight_layout()

ani = FuncAnimation(figure(figsize=(6,3)), animate, interval=1000)

plt.show()
end = timer.time()
print("Total time consumption {:.2f} seconds".format(end-start))
# Out:
# <img src="data:," width="0">
# Total time consumption 1116.98 seconds
